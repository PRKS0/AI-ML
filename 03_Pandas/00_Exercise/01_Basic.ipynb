# %%
import pandas as pd
import numpy as np
# pd.set_option('display.max_columns')
pd.set_option('display.width', 200)

# %% [markdown]
# Load the csv file into a Pandas Dataframe

# %%
df = pd.read_csv('../../../Data.csv')
print(df.head(10))
# Out:
#    ID                 Name  Age  Gender Department  Salary Joining_Date Performance_Score  Experience_Years  Bonus Remote_Work
# 0   1       Noah Hernandez   56    Male         IT   35486   2015-01-01         Excellent                18   8196          No
# 1   2           Ava Miller   46  Female         IT   38335   2015-01-16         Excellent                 9   4368         Yes
# 2   3  Charlotte Hernandez   32  Female    Finance  116900   2015-01-31              Poor                 8   4797          No
# 3   4        Ethan Johnson   25    Male         IT  119112   2015-02-15           Average                 4   2792          No
# 4   5       William Martin   38  Female         IT   41130   2015-03-02           Average                 5   6732         Yes
# 5   6         Olivia Davis   56  Female         IT  117508   2015-03-17           Average                19   4476         Yes
# ...

# %% [markdown]
# Basic information about data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 200 non-null    int64
#  1   Name               200 non-null    object
#  2   Age                200 non-null    int64
#  3   Gender             200 non-null    object
#  4   Department         200 non-null    object
#  5   Salary             200 non-null    int64
#  6   Joining_Date       200 non-null    object
#  7   Performance_Score  200 non-null    object
#  8   Experience_Years   200 non-null    int64
#  9   Bonus              200 non-null    int64
#  10  Remote_Work        200 non-null    object
# dtypes: int64(5), object(6)
# memory usage: 17.3+ KB

# %% [markdown]
# Summary statics for numerical columns

# %%
df.describe()           # describe the numerical (int, float) columns
df.describe(include='all')           # describe every types of column
# Out:
#                 ID                Name         Age  Gender Department         Salary Joining_Date Performance_Score  Experience_Years        Bonus Remote_Work
# count   200.000000                 200  200.000000     200        200     200.000000          200               200        200.000000   200.000000         200
# unique         NaN                 156         NaN       2          5            NaN          200                 4               NaN          NaN           2
# top            NaN  Charlotte Anderson         NaN  Female         IT            NaN   2015-01-01           Average               NaN          NaN         Yes
# freq           NaN                   3         NaN     107         47            NaN            1                56               NaN          NaN         109
# mean    100.500000                 NaN   38.665000     NaN        NaN   72013.830000          NaN               NaN          8.510000  5784.350000         NaN
# ...

# %%
# display all unique data in the Department column
df['Department'].unique()
# Out:
# array(['IT', 'Finance', 'HR', 'Sales', 'Marketing'], dtype=object)

# %%
# count the number of employees in each Gender
df['Gender'].value_counts()
# Out:
# Gender
# Female    107
# Male       93
# Name: count, dtype: int64

# %%
# filter rows where 'Age' is greater than 40
df[df['Age']>40]
# Out:
#       ID                Name  Age  Gender Department  Salary Joining_Date Performance_Score  Experience_Years  Bonus Remote_Work
# 0      1      Noah Hernandez   56    Male         IT   35486   2015-01-01         Excellent                18   8196          No
# 1      2          Ava Miller   46  Female         IT   38335   2015-01-16         Excellent                 9   4368         Yes
# 5      6        Olivia Davis   56  Female         IT  117508   2015-03-17           Average                19   4476         Yes
# 10    11  Alexander Williams   41  Female      Sales  114076   2015-05-31              Good                 0   4072         Yes
# 11    12           Ava Jones   53  Female         IT  119780   2015-06-15           Average                 5   2854         Yes
# ..   ...                 ...  ...     ...        ...     ...          ...               ...               ...    ...         ...
# ...

# %%
# show all employees from IT department
df[df['Department']=='IT']
# Out:
#       ID                Name  Age  Gender Department  Salary Joining_Date Performance_Score  Experience_Years  Bonus Remote_Work
# 0      1      Noah Hernandez   56    Male         IT   35486   2015-01-01         Excellent                18   8196          No
# 1      2          Ava Miller   46  Female         IT   38335   2015-01-16         Excellent                 9   4368         Yes
# 3      4       Ethan Johnson   25    Male         IT  119112   2015-02-15           Average                 4   2792          No
# 4      5      William Martin   38  Female         IT   41130   2015-03-02           Average                 5   6732         Yes
# 5      6        Olivia Davis   56  Female         IT  117508   2015-03-17           Average                19   4476         Yes
# 11    12           Ava Jones   53  Female         IT  119780   2015-06-15           Average                 5   2854         Yes
# ...

# %%
# find the maximum salary from dataset
df['Salary'].max()
# Out:
# np.int64(119930)

# %%
# get all the details of the employee with the highest "Experience_years"
df['Experience_Years'].max()
df[df['Experience_Years'] == 19]
# Out:
#       ID             Name  Age  Gender Department  Salary Joining_Date Performance_Score  Experience_Years  Bonus Remote_Work
# 5      6     Olivia Davis   56  Female         IT  117508   2015-03-17           Average                19   4476         Yes
# 24    25   Liam Rodriguez   39    Male  Marketing   53625   2015-12-27           Average                19   1536          No
# 43    44     Amelia Davis   19    Male  Marketing   72348   2016-10-07              Good                19   3713          No
# 45    46   James Gonzalez   45  Female  Marketing  113285   2016-11-06         Excellent                19   1966         Yes
# 69    70       Mia Taylor   40    Male         IT   55470   2017-11-01           Average                19   7645          No
# 133  134  Harper Anderson   21  Female    Finance  105672   2020-06-18           Average                19   5223          No
# ...
